# %% [markdown]
# Dataset inspection

# %%
import sys
import os

PROJECT_ROOT = os.getcwd()
sys.path.append(PROJECT_ROOT)

from src.dataset import inspect_coco_dataset

DATA_ROOT = "data"

inspect_coco_dataset(f"{DATA_ROOT}/train/annotations.json")
inspect_coco_dataset(f"{DATA_ROOT}/valid/annotations.json")
inspect_coco_dataset(f"{DATA_ROOT}/test/annotations.json")

# %% [markdown]
# Binary annotation generation

# %%
from src.dataset import convert_to_binary_coco

DATA_ROOT = "data"

convert_to_binary_coco(
    f"{DATA_ROOT}/train/annotations.json",
    f"{DATA_ROOT}/train/binary_annotations.json"
)

convert_to_binary_coco(
    f"{DATA_ROOT}/valid/annotations.json",
    f"{DATA_ROOT}/valid/binary_annotations.json"
)

convert_to_binary_coco(
    f"{DATA_ROOT}/test/annotations.json",
    f"{DATA_ROOT}/test/binary_annotations.json"
)

# %% [markdown]
# Binary dataset inspection

# %%
from src.dataset import inspect_coco_dataset

inspect_coco_dataset(f"{DATA_ROOT}/train/binary_annotations.json")
inspect_coco_dataset(f"{DATA_ROOT}/valid/binary_annotations.json")
inspect_coco_dataset(f"{DATA_ROOT}/test/binary_annotations.json")
